# %%
#Pandas
#para leitura da planilha e analise de dados

#pyautogui
#para movimentar o mouse e teclado

#openpyxl
#para leitura da planilha
# Out:
#   File "C:\Users\Rafael\AppData\Local\Temp/ipykernel_12108/1440348382.py", line 1
#     pip install pandas
#         ^
# SyntaxError: invalid syntax

# %%
pip install openpyxl
# Out:
# ...
#
# ...

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pyautogui
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#pip install sqlalchemy-access
# Out:
# ...
#   Attempting uninstall: pyodbc
#     Found existing installation: pyodbc 4.0.0-unsupported
#     Uninstalling pyodbc-4.0.0-unsupported:
#       Successfully uninstalled pyodbc-4.0.0-unsupported
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#pip install xlrd
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pyautogui
import time
import openpyxl
import pandas as pd
#import urllib
#from sqlalchemy import create_engine

# %%
pyautogui.alert("O código vai começar. Não use nada do seu computador enquanto o código estiver rodando!")
pyautogui.PAUSE = 0.5
#abrir o drive no pc
pyautogui.press('winleft')
pyautogui.write('Edge')
pyautogui.press('Enter')
time.sleep(1)
pyautogui.write("http://localhost:8888/notebooks/Arquivamento%20form.ipynb")
time.sleep(1)
pyautogui.press('enter')
time.sleep(1)
pyautogui.press('enter')
time.sleep(10)
pyautogui.hotkey('ctrl','enter')
time.sleep(5)
pyautogui.moveTo(250, 746)
pyautogui.click(250, 746)
pyautogui.press('tab')

# %%
#ler planilha de dados
tabela = pd.read_excel(r"C:\Users\Rafael\Dados Teste.xlsx")
display (tabela)
# Out:
#     Caixa  Ordem  Centro de Custo  Tipologia Data Abertura  \
# 0   10001      1               33         86    2021-06-08
# 1   10001      2               33         86    2021-06-08
# 2   10001      3               33         86    2021-06-08
# 3   10001      4               33         86    2021-06-08
# 4   10001      5               33         86    2021-06-08
# 5   10002      1               33         86    2021-06-08
# 6   10002      2               33         86    2021-06-08
# 7   10002      3               33         86    2021-06-08
# 8   10002      4               33         86    2021-06-08
# 9   10002      5               33         87    2021-06-08
# 10  10003      1               33         86    2021-06-08
# 11  10003      2               33         86    2021-06-08
# 12  10003      3               33         86    2021-06-08
# 13  10004      1               33         86    2021-06-08
# 14  10004      2               33         86    2021-06-08
# ...

# %%
tabela = pd.read_excel(r"C:\Users\Rafael\Dados Teste.xlsx").astype(str)
sistema = "http://localhost:8888/notebooks/Arquivamento%20form.ipynb"

pyautogui.alert("O código vai começar. Não use nada do seu computador enquanto o código estiver rodando!")
pyautogui.PAUSE = 0.5
#abrir o drive no pc
pyautogui.press('winleft')
pyautogui.write('Edge')
pyautogui.press('Enter')
time.sleep(1)
pyautogui.write(sistema)
time.sleep(1)
pyautogui.press('enter')
time.sleep(1)
pyautogui.press('enter')
time.sleep(10)
pyautogui.hotkey('ctrl','enter')
time.sleep(5)
pyautogui.moveTo(285, 743)
pyautogui.click(285, 743)
pyautogui.press('tab')

for i, Caixa in enumerate(tabela["Caixa"]):
    Ordem = tabela.loc[i,"Ordem"]
    Centro_de_Custo = tabela.loc[i,"Centro de Custo"]
    Tipologia = tabela.loc[i,"Tipologia"]
    Data_Abertura = tabela.loc[i,"Data Abertura"]
    Nome = tabela.loc[i,"Nome"]
    CPF = tabela.loc[i,"CPF"]
    CAD = tabela.loc[i,"CAD"]
    Incorporação = tabela.loc[i,"Incorporação"]
    Data_arquivo = tabela.loc[i,"Data arquivo"]
    Conta_Capital = tabela.loc[i,"Conta Capital"]
    SISBR = tabela.loc[i,"SISBR"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12456/2517310667.py in <module>
#      34     SISBR = tabela.loc[i,"SISBR"]
#      35
# ---> 36     Caixa = tabela.loc["Caixa"]
#      37
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     893
#     894             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 895             return self._getitem_axis(maybe_callable, axis=axis)
#     896
#     897     def _is_scalar_access(self, key: Tuple):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1122         # fall thru to straight lookup
#    1123         self._validate_key(key, axis)
# -> 1124         return self._get_label(key, axis=axis)
#    1125
#    1126     def _get_slice_axis(self, slice_obj: slice, axis: int):
#
# ...

# %% [markdown]
# pyautogui.typewrite('Caixa')
#     pyautogui.press('tab')
#     pyautogui.typewrite('Centro_de_Custo')
#     pyautogui.press('tab')
#     pyautogui.press('tab')
#     pyautogui.typewrite('Tipologia')
#     pyautogui.press('tab')
#     pyautogui.press('tab')
#     pyautogui.press('tab')
#     pyautogui.typewrite('Data_Abertura')
#     pyautogui.press('tab')
#     pyautogui.press('tab')
#     pyautogui.typewrite('Nome')
#     pyautogui.typewrite('CPF')
#     pyautogui.typewrite('CAD')
#     pyautogui.typewrite('Incorporação')
#     pyautogui.typewrite('Data_arquivo')
#     pyautogui.typewrite('Conta_Capital')
#     pyautogui.typewrite('SISBR')
